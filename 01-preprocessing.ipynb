# %%
import pandas as pd

df = pd.read_csv('datasets/crimes-in-baltimore.csv')

# Mengubah tipe data kolom "CrimeDateTime" menjadi datetime
df['CrimeDateTime'] = pd.to_datetime(df['CrimeDateTime'], errors='coerce')

# Mengidentifikasi baris yang menghasilkan kesalahan
out_of_bounds_rows = df[df['CrimeDateTime'].isna()]

# Menghapus baris yang menghasilkan kesalahan
df = df.drop(out_of_bounds_rows.index)

# Memisahkan kolom "CrimeDateTime" menjadi "CrimeDate" dan "CrimeTime"
df['CrimeDate'] = df['CrimeDateTime'].dt.strftime('%d/%m/%Y')
df['CrimeTime'] = df['CrimeDateTime'].dt.strftime('%H:%M:%S')

# Menghapus beberapa kolom yang tidak dibutuhkan
df = df.drop(['CrimeDateTime', 'RowID', 'CCNO', 'Gender', 'Age', 'Race', 'Ethnicity'], axis=1)

# Memindahkan kolom "CrimeDate" ke posisi 0
crime_date = df.pop('CrimeDate')
df.insert(0, 'CrimeDate', crime_date)

# Memindahkan kolom "CrimeTime" ke posisi 1
crime_time = df.pop('CrimeTime')
df.insert(1, 'CrimeTime', crime_time)

# Sort the DataFrame by 'CrimeDate' and 'CrimeTime'
df = df.sort_values(['CrimeDate', 'CrimeTime'])

# Reset the index of the sorted DataFrame
df = df.reset_index(drop=True)

print('Total Data: ' + str(len(df)))
print('======================')
df.head()
# Out:
# Total Data: 566643
# ======================
#     CrimeDate CrimeTime CrimeCode               Location Description  \
# 0  01/01/1966  01:00:00        2A        900 STAMFORD RD        RAPE
# 1  01/01/1978  00:00:00        2A   3600 W BELVEDERE AVE        RAPE
# 2  01/01/1978  00:00:00        2A  4300 PARK HEIGHTS AVE        RAPE
# 3  01/01/1978  10:30:00        2A        1900 ARGONNE DR        RAPE
# 4  01/01/1979  00:01:00        2A     800 BENNINGHAUS RD        RAPE
#
#   Inside_Outside Weapon   Post   District             Neighborhood   Latitude  \
# 0              I  OTHER  823.0  SOUTHWEST               WEST HILLS  39.296306
# 1            NaN  OTHER  633.0  NORTHWEST                ARLINGTON  39.346619
# 2              I  OTHER  614.0  NORTHWEST     CENTRAL PARK HEIGHTS  39.338898
# 3              I  OTHER  421.0  NORTHEAST  MORGAN STATE UNIVERSITY  39.340748
# 4              I  OTHER  523.0   NORTHERN                BELVEDERE  39.360133
#
#    Longitude                               GeoLocation            Premise  \
# 0 -76.709401  (39.296305974752784,-76.709400769778497)  ROW/TOWNHOUSE-OCC
# 1 -76.680174  (39.346618976119643,-76.680173520662322)                NaN
# 2 -76.665462  (39.338898480013256,-76.665462300931694)  ROW/TOWNHOUSE-OCC
# 3 -76.582734  (39.340747701096049,-76.582734031623119)  ROW/TOWNHOUSE-OCC
# 4 -76.603973  (39.360132718158731,-76.603973247731915)  ROW/TOWNHOUSE-OCC
#
#    Total_Incidents
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
# Mengubah format datetime dari kolom CrimeDate 
df['CrimeDate'] = pd.to_datetime(df['CrimeDate'], format='%d/%m/%Y')
# Filter berdasarkan tahunnya (2012-2018)
filtered_df = df[(df['CrimeDate'].dt.year >= 2012) & (df['CrimeDate'].dt.year <= 2018)]

# Simpan sebagai file csv baru
filtered_df.to_csv('datasets/filtered.csv')

print(len(filtered_df))
filtered_df.tail()
# Out:
# 339346
#         CrimeDate CrimeTime CrimeCode             Location Description  \
# 566273 2018-12-31  23:01:00        6B    400 N KENWOOD AVE     LARCENY
# 566274 2018-12-31  23:30:00        2A         600 FALLSWAY        RAPE
# 566275 2018-12-31  23:30:00        7A  2500 W BALTIMORE ST  AUTO THEFT
# 566276 2018-12-31  23:30:00        6E    2400 W LANVALE ST     LARCENY
# 566277 2018-12-31  23:32:00        6J       1500 MOSHER ST     LARCENY
#
#        Inside_Outside Weapon   Post   District         Neighborhood  \
# 566273              O    NaN  221.0  SOUTHEAST       MCELDERRY PARK
# 566274            NaN  OTHER  324.0    EASTERN        PENN-FALLSWAY
# 566275              O    NaN  835.0  SOUTHWEST         SHIPLEY HILL
# 566276              O    NaN  721.0    WESTERN       EVERGREEN LAWN
# 566277              O    NaN  724.0    WESTERN  SANDTOWN-WINCHESTER
#
#          Latitude  Longitude                               GeoLocation  \
# 566273  39.295899 -76.578039  (39.295898558427403,-76.578038752635862)
# 566274  39.296367 -76.610000  (39.296366658410619,-76.609999519334821)
# 566275  39.287866 -76.656607  (39.287865937854249,-76.656606575406443)
# 566276  39.297158 -76.655085  (39.297157727607015,-76.655085093749847)
# 566277  39.300143 -76.642596  (39.300143010886039,-76.642596171264387)
#
#                      Premise  Total_Incidents
# 566273  STREET                              1
# 566274                   NaN                1
# 566275  STREET                              1
# 566276  STREET                              1
# 566277  STREET                              1

# %%
# Lakukan filter SHOOTING khusus untuk kolom Description
df_shooting = filtered_df[filtered_df['Description'] == 'SHOOTING']

# Simpan sebagai file csv baru
df_shooting.to_csv('datasets/shooting.csv')

print(len(df_shooting))
df_shooting.tail()
# Out:
# 3116
#         CrimeDate CrimeTime CrimeCode            Location Description  \
# 566017 2016-12-31  17:58:00        9S       0 S HILTON ST    SHOOTING
# 566257 2018-12-31  22:08:00        9S  2800 SPRINGHILL AV    SHOOTING
# 566258 2018-12-31  22:08:00        9S     700 WHITMORE AV    SHOOTING
# 566263 2018-12-31  22:10:00        9S   1200 E PRESTON ST    SHOOTING
# 566264 2018-12-31  22:10:00        9S   1200 E PRESTON ST    SHOOTING
#
#        Inside_Outside   Weapon   Post   District    Neighborhood   Latitude  \
# 566017        Outside  FIREARM  835.0  SOUTHWEST   SAINT JOSEPHS  39.285422
# 566257        Outside  FIREARM  612.0  NORTHWEST     PARK CIRCLE  39.331266
# 566258        Outside  FIREARM  721.0    WESTERN  EVERGREEN LAWN  39.295557
# 566263        Outside  FIREARM  314.0    EASTERN          OLIVER  39.305131
# 566264        Outside  FIREARM  314.0    EASTERN          OLIVER  39.305131
#
#         Longitude                               GeoLocation      Premise  \
# 566017 -76.672448  (39.285422471524996,-76.672448261620346)  PARKING LOT
# 566257 -76.662881   (39.331266198075639,-76.66288100157351)       STREET
# 566258 -76.658166    (39.2955565493506,-76.658166447821344)  PUBLIC AREA
# 566263 -76.601749  (39.305130593546622,-76.601748899565564)  PUBLIC AREA
# 566264 -76.601749  (39.305130593546622,-76.601748899565564)  PUBLIC AREA
#
#         Total_Incidents
# 566017                1
# 566257                1
# 566258                1
# 566263                1
# 566264                1
